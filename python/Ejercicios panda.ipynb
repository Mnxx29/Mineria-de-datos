# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


df=pd.read_csv('superstore.csv')

df
# Out:
#           Transaction ID  Order ID  Customer ID  \
# 0     21865-109365-13542    109365        21865
# 1     15745-162026-16405    162026        15745
# 2     10090-136448-10461    136448        10090
# 3     16525-142993-23814    142993        16525
# 4      15280-115819-4927    115819        15280
# ...                  ...       ...          ...
# 9988   13540-132521-3244    132521        13540
# 9989  17560-143105-12682    143105        17560
# 9990  12250-149811-16023    149811        12250
# 9991  10300-166800-21126    166800        10300
# 9992  10720-136322-29264    136322        10720
#
#                                            Product Name Sub-Category  \
# 0                                              Xerox 22        Paper
# 1                                            Xerox 1925        Paper
# 2     Logitech 910-002974 M325 Wireless Mouse for We...  Accessories
# 3                Contico 72"H Heavy-Duty Storage System      Storage
# ...

# %%
print("Dimenciones del dataset: ",df.shape)
# Out:
# Dimenciones del dataset:  (9993, 17)

# %%
#Visualizar el nmbre de todas las columnas

df.columns.tolist()
# Out:
# ['Transaction ID',
#  'Order ID',
#  'Customer ID',
#  'Product Name',
#  'Sub-Category',
#  'Category',
#  'Discount',
#  'Order Date',
#  'Order Day',
#  'Order Month',
#  'Order Weekday',
#  'Order Year',
#  'Quantity',
#  'Segment',
#  'State',
#  'Profit CLP',
#  'Sales CLP']

# %%
#Imprimir iforacion sobre el dataframe, incluido el tipo de indice

print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9993 entries, 0 to 9992
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction ID  9993 non-null   str
#  1   Order ID        9993 non-null   int64
#  2   Customer ID     9993 non-null   int64
#  3   Product Name    9993 non-null   str
#  4   Sub-Category    9993 non-null   str
#  5   Category        9993 non-null   str
#  6   Discount        9993 non-null   float64
#  7   Order Date      9993 non-null   str
#  8   Order Day       9993 non-null   int64
#  9   Order Month     9993 non-null   int64
#  10  Order Weekday   9993 non-null   str
#  11  Order Year      9993 non-null   int64
#  12  Quantity        9993 non-null   int64
#  13  Segment         9993 non-null   str
#  14  State           9993 non-null   str
#  15  Profit CLP      9993 non-null   int64
#  16  Sales CLP       9993 non-null   int64
# dtypes: float64(1), int64(8), str(8)
# ...

# %%
#contabilizar nulls si aplica
pd.set_option('display.max_rows',None)
df.isna().sum()
# Out:
# Transaction ID    0
# Order ID          0
# Customer ID       0
# Product Name      0
# Sub-Category      0
# Category          0
# Discount          0
# Order Date        0
# Order Day         0
# Order Month       0
# Order Weekday     0
# Order Year        0
# Quantity          0
# Segment           0
# State             0
# Profit CLP        0
# Sales CLP         0
# dtype: int64

# %%
#imprmir las primera x filas

df.head(4)
# Out:
#        Transaction ID  Order ID  Customer ID  \
# 0  21865-109365-13542    109365        21865
# 1  15745-162026-16405    162026        15745
# 2  10090-136448-10461    136448        10090
# 3  16525-142993-23814    142993        16525
#
#                                         Product Name Sub-Category  \
# 0                                           Xerox 22        Paper
# 1                                         Xerox 1925        Paper
# 2  Logitech 910-002974 M325 Wireless Mouse for We...  Accessories
# 3             Contico 72"H Heavy-Duty Storage System      Storage
#
#           Category  Discount  Order Date  Order Day  Order Month  \
# 0  Office Supplies       0.0  2016-11-03          3           11
# 1  Office Supplies       0.0  2016-10-08          8           10
# 2       Technology       0.2  2017-09-16         16            9
# 3  Office Supplies       0.0  2015-10-12         12           10
#
# ...

# %%
#ver ultimas filas

df.tail(3)
# Out:
#           Transaction ID  Order ID  Customer ID  \
# 9990  12250-149811-16023    149811        12250
# 9991  10300-166800-21126    166800        10300
# 9992  10720-136322-29264    136322        10720
#
#                                            Product Name Sub-Category  \
# 9990  GBC Standard Recycled Report Covers, Clear Pla...      Binders
# 9991  Hoover Commercial Soft Guard Upright Vacuum An...   Appliances
# 9992                       GBC Personal VeloBind Strips      Binders
#
#              Category  Discount  Order Date  Order Day  Order Month  \
# 9990  Office Supplies       0.0  2015-01-04          4            1
# 9991  Office Supplies       0.0  2015-11-19         19           11
# 9992  Office Supplies       0.7  2016-10-21         21           10
#
#      Order Weekday  Order Year  Quantity      Segment      State  Profit CLP  \
# 9990        Sunday        2015         3    Corporate  Minnesota       12089
# ...

# %%
#seleccionar la columna "product name"
#string cuando es solo una variable
#para dos o mas variables, debe ser una lista


product_name=df["Product Name"]
product_name.head(10)
# Out:
# 0                                             Xerox 22
# 1                                           Xerox 1925
# 2    Logitech 910-002974 M325 Wireless Mouse for We...
# 3               Contico 72"H Heavy-Duty Storage System
# 4                        PowerGen Dual USB Car Charger
# 5             Hewlett Packard 310 Color Digital Copier
# 6    Acme Office Executive Series Stainless Steel T...
# 7                               GBC Instant Report Kit
# 8              DAX Black Cherry Wood-Tone Poster Frame
# 9                           GBC Durable Plastic Covers
# Name: Product Name, dtype: str
